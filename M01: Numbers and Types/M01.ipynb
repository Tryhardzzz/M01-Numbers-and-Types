# %%
60*60
# Out:
# 3600

# %%
seconds_per_hour = 3600
24 * seconds_per_hour
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour * 24

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Line 5 did not differ from Line 6 because there was no remainder, and the values of seconds per day and hour are the same through both calculations
